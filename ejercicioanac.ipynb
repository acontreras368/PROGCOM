# %% [markdown]
# # Revise la página https://www.researchgate.net/publication/273298847_Piedra_Papel_Tijera_y_sus_generalizaciones
# #Programe Piedra, papel, tijera, spock, lagarto, Papa y heavy usando arreglos.

# %%
import random 
op=['Piedra', 'Papel','Tijera','Lagarto','Papa','Heavy', 'Spock']

elec=random.randint(0,6)
pc=op[elec]
print("La elección del compu es: ", pc)
persona=input("Digita tu elección así tal cual: Piedra, Papel, Tijera, Spock, Lagarto, Papa o Heavy")

if (persona==pc):
  print("Empate")

if(persona=='Tijera'):
  if (pc=="Papel"):
    print("Ganaste")
  if (pc=="Piedra"):
    print("Perdiste")
  if (pc=="Lagarto"):
    print("Ganaste")
  if (pc=="Spock"):
    print("Perdiste")
  if (pc=="Papa"):
    print("Perdiste")
  if (pc=="Heavy"):
    print("Ganaste")

if(persona=='Papel'):
  if (pc=="Tijera"):
    print("Perdiste")
  if (pc=="Piedra"):
    print("Ganaste")
  if (pc=="Spock"):
    print("Ganaste")
  if (pc=="Lagarto"):
    print("Perdiste")
  if (pc=="Papa"):
    print("Perdiste")
  if (pc=="Heavy"):
    print("Ganaste")
  

if(persona=='Piedra'):
  if (pc=="Tijera"):
    print("Ganaste")
  if (pc=="Papel"):
    print("Perdiste")
  if (pc=="Lagardo"):
    print("Ganaste")
  if (pc=="Heavy"):
    print("Ganaste")
  if (pc=="Papa"):
    print("Perdiste")
  if (pc=="Heavy"):
    print("Ganaste")

if(persona=='Lagarto'):
  if (pc=="Spock"):
    print("Perdiste")
  if (pc=="Papel"):
    print("Ganaste")
  if (pc=="Papa"):
    print("Perdiste")
  if (pc=="Papa"):
    print("Ganaste")
  if (pc=="Heavy"):
    print("Perdiste")
  if (pc=="Piedra"):
    print("Perdiste")

if(persona=='Spock'):
  if (pc=="Tijera"):
    print("Ganaste")
  if (pc=="Piedra"):
    print("Ganaste")
  if (pc=="Papa"):
    print("Ganaste")
  if (pc=="Lagarto"):
    print("Perdiste")
  if (pc=="Heavy"):
    print("Perdiste")
  if (pc=="Papel"):
    print("Perdiste")

if(persona=='Heavy'):
  if (pc=="Spock"):
    print("Ganaste")
  if (pc=="Lagarto"):
    print("Ganaste")
  if (pc=="Papa"):
    print("Ganaste")
  if (pc=="Piedra"):
    print("Perdiste")
  if (pc=="Papel"):
    print("Perdiste")
  if (pc=="Tijera"):
    print("Perdiste")



if(persona=='Papa'):
  if (pc=="Tijera"):
    print("Ganaste")
  if (pc=="Papel"):
    print("Ganaste")
  if (pc=="Piedra"):
    print("Ganaste")
  if (pc=="Spock"):
    print("Perdiste")
  if (pc=="Lagarto"):
    print("Perdiste")
  if (pc=="Heavy"):
    print("Perdiste")
